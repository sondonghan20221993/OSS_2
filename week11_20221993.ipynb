# %%
class Foo:
    def __getitem__(self, pos):
        return range(0, 30, 10)[pos]

# %%
f[1]
# Out:
# 10

# %%
f = Foo()
for i in f: print(i)
# Out:
# 0
# 10
# 20

# %%
20 in f
# Out:
# True

# %%
15 in f
# Out:
# False

# %%
import collections
Card = collections.namedtuple('Card', ['rank', 'suit'])

class FrenchDeck():
    ranks = [str(n) for n in range(2, 11)] + list('JQKA')
    suits = 'spades diamonds clubs hearts'.split()

    def __init__(self):
        self.cards = [Card(rank, suit) for suit in self.suits for rank in self.ranks]

    def __len__(self):
        return len(self._cards)

    def __getitem__(self, position):
        return self._cards[position]

# %%
from random import shuffle
##from frenchdeck import FrenchDeck
deck=FrenchDeck()
shuffle(deck)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4066514040.py in <cell line: 0>()
#       2 ##from frenchdeck import FrenchDeck
#       3 deck=FrenchDeck()
# ----> 4 shuffle(deck)
#
# /usr/lib/python3.12/random.py in shuffle(self, x)
#     352
#     353         randbelow = self._randbelow
# --> 354         for i in reversed(range(1, len(x))):
#     355             # pick an element in x[:i+1] with which to exchange x[i]
#     356             j = randbelow(i + 1)
#
# /tmp/ipython-input-2085148792.py in __len__(self)
#      10
#      11     def __len__(self):
# ---> 12         return len(self._cards)
#      13
#      14     def __getitem__(self, position):
#
# AttributeError: 'FrenchDeck' object has no attribute '_cards'

# %%
def set_card(deck, position, card):
    deck._cards[position] = card

FrenchDeck.__setitem__ = set_card
shuffle(deck)
deck[:5]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1569188884.py in <cell line: 0>()
#       3
#       4 FrenchDeck.__setitem__ = set_card
# ----> 5 shuffle(deck)
#       6 deck[:5]
#
# /usr/lib/python3.12/random.py in shuffle(self, x)
#     352
#     353         randbelow = self._randbelow
# --> 354         for i in reversed(range(1, len(x))):
#     355             # pick an element in x[:i+1] with which to exchange x[i]
#     356             j = randbelow(i + 1)
#
# /tmp/ipython-input-2085148792.py in __len__(self)
#      10
#      11     def __len__(self):
# ---> 12         return len(self._cards)
#      13
#      14     def __getitem__(self, position):
#
# AttributeError: 'FrenchDeck' object has no attribute '_cards'

# %%
import collections

Card = collections.namedtuple('Card', ['rank', 'suit'])

class FrenchDeck2():
    ranks = [str(n) for n in range(2, 11)] + list('JQKA')
    suits = 'spades diamonds clubs hearts'.split()

    def __init__(self):
        self._cards = [Card(rank, suit) for suit in self.suits for rank in self.ranks]

    def __len__(self):
        return len(self._cards)

    def __getitem__(self, position):
        return self._cards[position]

    def __setitem__(self, position, value):
        self._cards[position] = value

    def __delitem__(self, position):
        del self._cards[position]

    def insert(self, position,value):
        self._cards.insert(position, value)

# %%
import abc

class Tombola(abc.ABC):

    @abc.abstractmethod
    def load(self, iterable):
        """Add items from an iterable"""

    @abc.abstractmethod
    def pick(self):
        """Remove item at random, returning it.

        This method should raise 'LookupError' when the instance is empty.
        """

    def loaded(self):
        """Return 'True' if there`s at least 1 item, 'False' ootherwise."""
        return bool(self.inspect())

    def inspect(self):
        """Return a sorted tuple with the items currently inside."""
        items = []
        while True:
            try:
                items.append(self.pick())
            except LookupError:
                break
        self.load(items)
        return tuple(sorted(items))

# %%
import random

##from tombola import Tombola
class BingoCage(Tombola):

    def __init__(self, items):
        self._randomizer = random.SystemRandom()
        self._items = []
        self.load(items)

    def load(self, items):
        self._items.extend(items)
        self._randomizer.shuffle(self._items)

    def pick(self):
        try:
            return self._items.pop()
        except IndexError:
            raise LookupError('pick from empty BingoCage')
    def __call__(self):
        self.pick()

# %%
def inspect(self):
    """Return a sorted tuple with the items currently inside."""
    items = []
    while True:
        try:
            items.append(self.pick)()
        except LookupError:
            break
    self.load(items)
    return tuple(sorted(items))

# %%
import random

##from tombola import Tombola

class LotteryBlower(Tombola):

    def __init__(self, iterable):
        self._balls = list(iterable)

    def load(self, iterable):
        self._balls.extend(iterable)

    def pick(self):
        try:
            position = random.randrange(len(self._balls))
        except ValueError:
            raise LookupError('pick from empty BingoCage')
        return self._balls.pop(position)

    def loaded(self):
        return bool(self._balls)

    def inspect(self):
        return tuple(sorted(self._balls))

# %%
from random import randrange
#from tombola import Tombola

@Tombola.register
class TomboList(list):

    def pick(self):
        if self:
            position = randrange(len(self))
            return self.pop(position)
        else:
            raise LookupError('pop from empty TomboList')

    load = list.extend

    def loaded(self):
        return bool(self)

    def inspect(self):
        return tuple(sorted(self))
